# %% [markdown]
# <a id="top"></a>
# #  Stock Performance with Yahoo! Finance (yfinance)
#
# **Yahoo! Finance** https://finance.yahoo.com/ is an excellent, free website that provides investment and financial information, including news, stock quotes, press releases, reports and more.  It is a the go-to site for all news and data on markets, investments and stocks.
#
# **yfinance** is the Python library for downloading financial data from **Yahoo! Finance**.  This notebook is a step-by-step guide on using **yfinance** to bulk download market and stock data, create dataframes and calculate the percentage returns and compare the returns over time.
#
# **Source**: https://www.kaggle.com/code/asimislam/stock-performance-with-yahoo-finance-yfinance
#
# ---
#
# ### Table of Content
# 1. [Select Securities and Time Intervals](#symbols)<br>
# <br>
# 2. [Financial Information](#yf_ticker) - download with `yf.Ticker(x).info`<br>
# <br>
# 3. [Percentage Returns](#yf_download)<br>
#     3.1 [Download Historical Prices](#yf_download_price) - bulk download `yf.download`<br>
#     3.2 [Download Dividend Data](#yf_download_div) - download with `yf.Ticker(x).dividends`<br>
#     3.3 [Calculate Percentage Returns](#yf_download_ret) - calculate with `df.pct_change`<br>
#     3.4 [Clean-Up Return's Dataframe](#yf_download_clean)<br>
# <br>
# 4. [Performance Analysis](#perf)<br>
#     4.1 [Performance - YEARLY](#perf_yr)<br>
#     4.2 [Performance - MONTHLY](#perf_mh)<br>
#     4.3 [Performance - WEEKLY](#perf_wk)<br>
#     4.4 [Performance - DAILY](#perf_dy)<br>
# <br>
# 5.  [Financial Markets and Investment Overview](#stock_markets)<br>
#     5.1  [Financial Markets](#fin_markets)<br>
#     5.2  [Market Indexes](#market_index)<br>
#     5.3  [Financial Instruments](#fin_inst)<br>
#     5.4  [Investment Instruments](#inv_inst)<br>
#
#
# ---
#
#
# <font size="4">A few things before we get started:</font>
#
# - any valid **financial symbol** (market indexes, stocks, bonds, funds, etc.) can be used
# - **Equity**, **Security**, **Stock**, **Symbol** and **Ticker** are used interchangeably for any [Financial Instruments](#fin_inst) or [Investment Instruments](#inv_inst)
# - **Market**, **Index** and **Market Index** are used interchangeably for [Financial Markets](#fin_markets) or [Market Indexes](#market_index)<br>
# <br>
# - For each ticker, `yfinance` returns price as a *number* and dividends as a *percentage*.  Therefore, **returns as percentages** are caluculated as:
#
# \begin{align*}
# \mathsf{\text{Percentage Return} =  \frac{price_{2}-price_{1}}{price_{1}}} \times  100 + dividends (\%)
# \end{align*}
#
# ---
# **references:**
# [yfinance - PyPI](#https://pypi.org/project/yfinance/)<br>
# [Get Financial Data from Yahoo Finance with Python](#https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)
#
# **This notebook is only a helpful tool and not financial advice!**<br>
# **Please upvote if you found this useful** :-)

# %% [markdown]
# ---
# ### Import Libraries

# %%
import pandas   as pd             # dataframe
import seaborn  as sns            # plots
import matplotlib.pyplot as plt   # plots

try:
    import yfinance as yf         # import Yahoo! Finance
except:
    ! pip install yfinance
    import yfinance as yf         # import Yahoo! Finance

# %% [markdown]
# Use `!pip install yfinance` to install Yahoo! Finance.
#
# ---
# <a id="symbols"></a>
# # 1.  Select Securities and Time Period
#
# ---
#
# ### Parameters in this Notebook:
# <span style="color:blue"><font size="4">This is the only section where paramerters are set.</font></span>
# - set `ticker`
# - set `yf_period`
# - set `yf_interval`
#
# |  parameter | description | | user input required |
# | :--- | :--- | :--- | :---: |
# | **ticker** | stocks to analyze | `list` | yes |
# | **market_index** | US market indexes | `list` | no |
# | **symbols** | = ticker + market indexes | `list` | no |
# | **fin_info** | financial information  | `list` | no |
# | **yf_period** | span of time to investigate | `constant` | yes |
# | **yf_interval** | increments within yf_period | `constant` | yes |
#
# ---
#
# ### DataFrames Created in this Notebook:
#
# - download securities information `yf_info`
# - download historical prices `yf_returns`
# - download dividend data `yf_divdend`
#
# |  DataFrame | Description | library | method | download time |
# | :--- | :--- | :--- | :--- | :---: |
# | **yf_info** | financial information  | **yfinance** | `yf.Ticker.info()`| < 2 min. |
# | **yf_returns** | historical prices  | **yfinance** | `yf.download()` | < 1 min. |
# | **yf_returns** | percentage change | **pandas** | `.pct_change()` | - from `yf_returns` |
# | **yf_divdend** | dividend payouts  | **yfinance** | `yf.Ticker.dividends()` | < 1 min. |
# ||||||
# | **perf_yr** | annual information | **pandas** | `.groupby(YEAR)` |  |
# | **perf_mh** | monthly information | **pandas** | `.groupby(YEAR-MONTH)` |  |
# | **perf_wk** | weekly information | **pandas** | `.groupby(YEAR-WEEK)` |  |
# | **perf_dy** | daily information | **pandas** | | - same as `yf_returns` |
#
# ---

# %%
#  SET ticker, yf_period and yf_interval
#  ticker - securities to download

sp_500 = pd.read_csv('sp_500.csv')


# sp_stocks = sp_500.Symbol.tolist()

# ticker      = ["amzn", "FBgrx", "qqq", "VBTLX", 'twtr', 'FLT', '^dji']
ticker = sp_500.Symbol.tolist()

#  set market indexes to compare equities with
market_index = ['^DJI', '^IXIC', '^GSPC']  # Dow Jones, Nasdaq and S&P500

#  time period and interval
yf_period   = "10y"   # 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
yf_interval = "1d"    # 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo



#  print set parameters
print('TICKER:\t\t{}'.format(ticker))
print('MARKET INDEX:\t{}'.format(market_index))
print('PERIOD:\t\t{}'.format(yf_period))
print('INTERVAL:\t{}'.format(yf_interval))
# Out:
# TICKER:		['MMM', 'AOS', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FAST', 'FRT', 'FDX', 'FITB', 'FRC', 'FSLR', 'FE', 'FIS', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SBNY', 'SPG', 'SWKS', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VNO', 'VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# MARKET INDEX:	['^DJI', '^IXIC', '^GSPC']
# PERIOD:		10y
# INTERVAL:	1d

# %% [markdown]
# ---

# %% [markdown]
# <span style="color:b"><font size="5">SYMBOLS = MARKET INDEXES + TICKER</font></span>

# %%
#  1.  uppercase and sort ticker
ticker = [x.upper() for x in ticker]
ticker.sort()


#  2.  set market indexes
market_index = ['^DJI', '^IXIC', '^GSPC']  # Dow Jones, Nasdaq and S&P500


#  3.  remove markets from ticker for plots, returns
for market in market_index:
    if market in ticker:
        ticker.remove(market)


#  4.  symbols = market_indexes + ticker
symbols = []   # initialize list
symbols = ticker + market_index


#  print set parameters
print('\nSYMBOLS (ticker + market index):\n{}'.format(symbols))
# Out:
# SYMBOLS (ticker + market index):
# ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'AB
 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'POOL', 'PPG', 'PPL', 'PRU', 'PSA', 'PSX', 'PTC', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RTX', 'SBAC', 'SBNY', 'SBUX', 'SCHW', 'SEDG', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STE', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TDY', 'TECH', 'TEL', 'TER', 'TFC', 'TFX', 'TGT', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRGP', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT', 'TTWO', 'TXN', 'TXT', 'TYL', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC', 'VICI', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS', 'VZ', 'WAB', 'WAT', 'WBA', 'WBD', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WTW', 'WY', 'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS', '^DJI', '^IXIC', '^GSPC']

# %% [markdown]
# [go to top](#top)
#
# ---
# <a id="yf_ticker"></a>
# # 2.  Financial Information
# The **yf.Ticker** method gives general information about the symbol, such as name, sector, EPS, PE, market capitalization, etc.  See below for [full list](#parameters) of parameters.
#
# Steps:
# 1.  Select the information parameters, `fin_parameters` to download
# 2.  Download symbol information using `yf.Ticker`
# 3.  Create the dataframe, `yf_info`

# %%
#  set parameters to download
fin_info = ["shortName", "sector", "industry", "quoteType", "exchange", "totalAssets", "marketCap", "beta", "trailingPE", "volume", "averageVolume", "fiftyTwoWeekLow", "fiftyTwoWeekHigh", "dividendRate", "phone"]

#  create dataframe
yf_info = pd.DataFrame(index = fin_info, columns = symbols)

for i in symbols:
    l = []             # initialize
    x = yf.Ticker(i)   # get ticker info
    for j in fin_info:
        if 'date' in j.lower():
            d = pd.to_datetime(x.info[j])
            if d is not None:
                l.append(d.strftime("%Y-%m-%d"))  # format date
        else:
            try:      # some parameters error
                l.append(x.info[j])
            except:   # ignore error and continue
                l.append("")
    yf_info[i] = l
    print('{}\t- financial information downloaded'.format(i))


yf_info
# Out:
# A	- financial information downloaded
# AAL	- financial information downloaded
# AAP	- financial information downloaded
# AAPL	- financial information downloaded
# ABBV	- financial information downloaded
# ABC	- financial information downloaded
# ABMD	- financial information downloaded
# ABT	- financial information downloaded
# ACGL	- financial information downloaded
# ACN	- financial information downloaded
# ADBE	- financial information downloaded
# ADI	- financial information downloaded
# ADM	- financial information downloaded
# ADP	- financial information downloaded
# ADSK	- financial information downloaded
# AEE	- financial information downloaded
# AEP	- financial information downloaded
# AES	- financial information downloaded
# AFL	- financial information downloaded
# AIG	- financial information downloaded
# AIZ	- financial information downloaded
# AJG	- financial information downloaded
# AKAM	- financial information downloaded
# ALB	- financial information downloaded
# ALGN	- financial information downloaded
# ALK	- financial information downloaded
# ALL	- financial information downloaded
# ALLE	- financial information downloaded
# AMAT	- financial information downloaded
# AMCR	- financial information downloaded
# AMD	- financial information downloaded
# AME	- financial information downloaded
# AMGN	- financial information downloaded
# AMP	- financial information downloaded
# AMT	- financial information downloaded
# AMZN	- financial information downloaded
# ANET	- financial information downloaded
# ANSS	- financial information downloaded
# AON	- financial information downloaded
# AOS	- financial information downloaded
# APA	- financial information downloaded
# APD	- financial information downloaded
# APH	- financial information downloaded
# APTV	- financial information downloaded
# ARE	- financial information downloaded
# ATO	- financial information downloaded
# ATVI	- financial information downloaded
# AVB	- financial information downloaded
# AVGO	- financial information downloaded
# AVY	- financial information downloaded
# AWK	- financial information downloaded
# AXP	- financial information downloaded
# AZO	- financial information downloaded
# BA	- financial information downloaded
# BAC	- financial information downloaded
# BALL	- financial information downloaded
# BAX	- financial information downloaded
# BBWI	- financial information downloaded
# BBY	- financial information downloaded
# BDX	- financial information downloaded
# BEN	- financial information downloaded
# BF.B	- financial information downloaded
# BIIB	- financial information downloaded
# BIO	- financial information downloaded
# BK	- financial information downloaded
# BKNG	- financial information downloaded
# BKR	- financial information downloaded
# BLK	- financial information downloaded
# BMY	- financial information downloaded
# BR	- financial information downloaded
# BRK.B	- financial information downloaded
# BRO	- financial information downloaded
# BSX	- financial information downloaded
# BWA	- financial information downloaded
# BXP	- financial information downloaded
# C	- financial information downloaded
# CAG	- financial information downloaded
# CAH	- financial information downloaded
# CARR	- financial information downloaded
# CAT	- financial information downloaded
# CB	- financial information downloaded
# CBOE	- financial information downloaded
# CBRE	- financial information downloaded
# CCI	- financial information downloaded
# CCL	- financial information downloaded
# CDAY	- financial information downloaded
# CDNS	- financial information downloaded
# CDW	- financial information downloaded
# CE	- financial information downloaded
# CEG	- financial information downloaded
# CF	- financial information downloaded
# CFG	- financial information downloaded
# CHD	- financial information downloaded
# CHRW	- financial information downloaded
# CHTR	- financial information downloaded
# CI	- financial information downloaded
# CINF	- financial information downloaded
# CL	- financial information downloaded
# CLX	- financial information downloaded
# CMA	- financial information downloaded
# CMCSA	- financial information downloaded
# CME	- financial information downloaded
# CMG	- financial information downloaded
# CMI	- financial information downloaded
# CMS	- financial information downloaded
# CNC	- financial information downloaded
# CNP	- financial information downloaded
# COF	- financial information downloaded
# COO	- financial information downloaded
# COP	- financial information downloaded
# COST	- financial information downloaded
# CPB	- financial information downloaded
# CPRT	- financial information downloaded
# CPT	- financial information downloaded
# CRL	- financial information downloaded
# CRM	- financial information downloaded
# CSCO	- financial information downloaded
# CSGP	- financial information downloaded
# CSX	- financial information downloaded
# CTAS	- financial information downloaded
# CTLT	- financial information downloaded
# CTRA	- financial information downloaded
# CTSH	- financial information downloaded
# CTVA	- financial information downloaded
# CVS	- financial information downloaded
# CVX	- financial information downloaded
# CZR	- financial information downloaded
# D	- financial information downloaded
# DAL	- financial information downloaded
# DD	- financial information downloaded
# DE	- financial information downloaded
# DFS	- financial information downloaded
# DG	- financial information downloaded
# DGX	- financial information downloaded
# DHI	- financial information downloaded
# DHR	- financial information downloaded
# DIS	- financial information downloaded
# DISH	- financial information downloaded
# VLO	- financial information downloaded
# VMC	- financial information downloaded
# VNO	- financial information downloaded
# VRSK	- financial information downloaded
# VRSN	- financial information downloaded
# VRTX	- financial information downloaded
# VTR	- financial information downloaded
# VTRS	- financial information downloaded
# VZ	- financial information downloaded
# WAB	- financial information downloaded
# WAT	- financial information downloaded
# WBA	- financial information downloaded
# WBD	- financial information downloaded
# WDC	- financial information downloaded
# WEC	- financial information downloaded
# WELL	- financial information downloaded
# WFC	- financial information downloaded
# WHR	- financial information downloaded
# WM	- financial information downloaded
# WMB	- financial information downloaded
# WMT	- financial information downloaded
# WRB	- financial information downloaded
# WRK	- financial information downloaded
# WST	- financial information downloaded
# WTW	- financial information downloaded
# WY	- financial information downloaded
# WYNN	- financial information downloaded
# XEL	- financial information downloaded
# XOM	- financial information downloaded
# XRAY	- financial information downloaded
# XYL	- financial information downloaded
# YUM	- financial information downloaded
# ZBH	- financial information downloaded
# ZBRA	- financial information downloaded
# ZION	- financial information downloaded
# ZTS	- financial information downloaded
# ^DJI	- financial information downloaded
# ^IXIC	- financial information downloaded
# ^GSPC	- financial information downloaded
#                                            A                            AAL  \
# shortName         Agilent Technologies, Inc.  American Airlines Group, Inc.
# sector                            Healthcare                    Industrials
# industry              Diagnostics & Research                       Airlines
# quoteType                             EQUITY                         EQUITY
# exchange                                 NYQ                            NMS
# totalAssets                             None                           None
# marketCap                        45197467648                     8181339136
# beta                                1.040162                       1.450626
# trailingPE                         57.628036
# volume                                467118                       13170808
# averageVolume                        1366744                       30768373
# fiftyTwoWeekLow                       112.52                          11.65
# fiftyTwoWeekHigh                      162.62                          21.42
# dividendRate                            0.84                           None
# phone                           800 227 9770                   682 278 9000
#
#                                       AAP                  AAPL  \
# shortName         Advance Auto Parts Inc.            Apple Inc.
# sector                  Consumer Cyclical            Technology
# industry                 Specialty Retail  Consumer Electronics
# quoteType                          EQUITY                EQUITY
# exchange                              NYQ                   NMS
# totalAssets                          None                  None
# marketCap                      8942359552         2161789239296
# beta                             1.237656              1.249815
# trailingPE                      20.085436             29.616768
# volume                             290881              50726901
# averageVolume                     1014333              86902100
# fiftyTwoWeekLow                    138.52                129.04
# fiftyTwoWeekHigh                   244.55                182.94
# dividendRate                            6                  0.92
# phone                        540 362 4911          408 996 1010
#
#                                         ABBV                            ABC  \
# shortName                        AbbVie Inc.  AmerisourceBergen Corporation
# sector                            Healthcare                     Healthcare
# industry          Drug Manufacturers—General           Medical Distribution
# quoteType                             EQUITY                         EQUITY
# exchange                                 NYQ                            NYQ
# totalAssets                             None                           None
# marketCap                       288305872896                    35431727104
# beta                                0.647383                       0.497052
# trailingPE                          55.98352
# volume                               1406431                         287950
# averageVolume                        5606301                        1522174
# fiftyTwoWeekLow                       128.26                         127.94
# fiftyTwoWeekHigh                      175.91                         174.63
# dividendRate                            5.64                           1.84
# phone                           847 932 7900                   610 727 7000
#
#                              ABMD                  ABT  \
# shortName           ABIOMED, Inc.  Abbott Laboratories
# sector                 Healthcare           Healthcare
# industry          Medical Devices      Medical Devices
# quoteType                  EQUITY               EQUITY
# exchange                      NMS                  NYQ
# totalAssets                  None                 None
# marketCap             17335457792         190904598528
# beta                     1.314296             0.709285
# trailingPE              77.129555            33.822056
# volume                   15702662              1665615
# averageVolume             1441806              5902326
# fiftyTwoWeekLow            219.85                93.25
# fiftyTwoWeekHigh           381.99                142.6
# dividendRate                 None                 1.88
# phone                978 646 1400         224 667 6100
#
#                                      ACGL                              ACN  \
# shortName         Arch Capital Group Ltd.                    Accenture plc
# sector                 Financial Services                       Technology
# industry            Insurance—Diversified  Information Technology Services
# quoteType                          EQUITY                           EQUITY
# exchange                              NMS                              NYQ
# totalAssets                          None                             None
# marketCap                     24492480512                     168361246720
# beta                                 None                         1.213706
# trailingPE                      15.638559                        31.500591
# volume                             525010                           811439
# averageVolume                     4019307                          2269931
# fiftyTwoWeekLow                     41.05                           242.95
# fiftyTwoWeekHigh                    63.53                           417.37
# dividendRate                         None                             4.48
# phone                                                       353 1 646 2000
#
#                   ...                            XRAY  \
# shortName         ...            DENTSPLY SIRONA Inc.
# sector            ...                      Healthcare
# industry          ...  Medical Instruments & Supplies
# quoteType         ...                          EQUITY
# exchange          ...                             NMS
# totalAssets       ...                            None
# marketCap         ...                      6942958592
# beta              ...                         0.94252
# trailingPE        ...
# volume            ...                          864655
# averageVolume     ...                         2391026
# fiftyTwoWeekLow   ...                           26.48
# fiftyTwoWeekHigh  ...                            58.7
# dividendRate      ...                             0.5
# phone             ...                    844-848-0137
#
#                                              XYL                YUM  \
# shortName                             Xylem Inc.  Yum! Brands, Inc.
# sector                               Industrials  Consumer Cyclical
# industry          Specialty Industrial Machinery        Restaurants
# quoteType                                 EQUITY             EQUITY
# exchange                                     NYQ                NYQ
# totalAssets                                 None               None
# marketCap                            19822729216        37805363200
# beta                                    1.062638           1.001105
# trailingPE                              78.51986           34.49318
# volume                                    155111             409524
# averageVolume                             919211            1881887
# fiftyTwoWeekLow                            72.08             103.97
# fiftyTwoWeekHigh                          121.05             139.85
# dividendRate                                 1.2               2.28
# phone                               914 323 5700       502 874 8300
#
#                                            ZBH  \
# shortName         Zimmer Biomet Holdings, Inc.
# sector                              Healthcare
# industry                       Medical Devices
# quoteType                               EQUITY
# exchange                                   NYQ
# totalAssets                               None
# marketCap                          26368368640
# beta                                  1.075902
# trailingPE
# volume                                  542504
# averageVolume                          1229031
# fiftyTwoWeekLow                         100.39
# fiftyTwoWeekHigh                        135.05
# dividendRate                              0.96
# phone                             574 267 6131
#
#                                             ZBRA                       ZION  \
# shortName         Zebra Technologies Corporation  Zions Bancorporation N.A.
# sector                                Technology         Financial Services
# industry                 Communication Equipment             Banks—Regional
# quoteType                                 EQUITY                     EQUITY
# exchange                                     NMS                        NMS
# totalAssets                                 None                       None
# marketCap                            13273799680                 7590020096
# beta                                    1.662859                   1.207074
# trailingPE                             26.564705                    9.86176
# volume                                    126368                     706909
# averageVolume                             478782                    1519084
# fiftyTwoWeekLow                           224.87                      45.21
# fiftyTwoWeekHigh                          609.32                      75.44
# dividendRate                                None                       1.64
# phone                               847 634 6700               801 844 7637
#
#                                                      ZTS  \
# shortName                                    Zoetis Inc.
# sector                                        Healthcare
# industry          Drug Manufacturers—Specialty & Generic
# quoteType                                         EQUITY
# exchange                                             NYQ
# totalAssets                                         None
# marketCap                                    68674236416
# beta                                            0.760869
# trailingPE                                     42.441517
# volume                                            642660
# averageVolume                                    2376298
# fiftyTwoWeekLow                                   124.15
# fiftyTwoWeekHigh                                  249.27
# dividendRate                                         1.3
# phone                                       973 822 7000
#
#                                           ^DJI             ^IXIC       ^GSPC
# shortName         Dow Jones Industrial Average  NASDAQ Composite     S&P 500
# sector
# industry
# quoteType                                INDEX             INDEX       INDEX
# exchange                                   DJI               NIM         SNP
# totalAssets                               None              None        None
# marketCap                                 None              None        None
# beta                                      None              None        None
# trailingPE
# volume                               167416475        2426709000  1167342000
# averageVolume                        360473650        4816021111  4496892857
# fiftyTwoWeekLow                       28660.94          10088.83     3491.58
# fiftyTwoWeekHigh                      36952.65          15901.47     4818.62
# dividendRate                              None              None        None
# phone
#
# [15 rows x 506 columns]

# %% [markdown]
# *table above can be reworded as:*<br>
#
# **MARKET INDEXES**
# * **Dow Jones Industrial Average** `^DJI` is a US market index
# * **S&P 500** `^GSPC` is a US market index
# * **NASDAQ Composite** `^IXIC` is a US market index
# <br>
#
# **EQUITY**
# *  **Amazon.com, Inc.** `AMZN` is an **equity** in the **consumer cyclical** sector and **internet retail** industry with a **market capitalization** of \\$1,2 Trillion.  The stock has been trading for the past year with an **average daily volume** of 3.6 million shares, with **share prices** ranging between \\$2367 and \\$3773.
# <br>
# *  **FleetCor Technologies, Inc.** `FLT` is an **equity** in the **Technology** sector and **Software Infrastructure** industry with a **market capitalization** of \\$16.7 Billion.  The stock has been trading for the past year with an **average daily volume** of half-a-millionn shares, with **share prices** ranging between \\$200 and \\$282.
# <br>
# *  **Twitter, Inc.** `TWTR` is an **equity** in the **Communication Services** sector and **Communication Services** industry with a **market capitalization** of \\$36.9 Billion.  The stock has been trading for the past year with an **average daily volume** of 51 Million shares, with **share prices** ranging between \\$31 and \\$73.
# <br>
#
# **EXCHANGE-TRADED FUND (ETF)**
# *  Invesco QQQ Trust, Series 1 (**QQQ**) is an **ETF** with \\$196 Billion in assets.  The fund has been trading for the past year with **share prices** ranging between \\$290 and \\$410.
# <br>
#
# **MUTUAL FUND**
# *  **Fidelity Blue Chip Growth Fund** `FBGRX` is a **mutual fund**.  No other information is available at this time.
# <br>
# *  **Vanguard Total Bond Market** `VBTLX` is a **mutual fund** with $316 Billion in assets.
# <br>
#
# **CRYPTOCURRENCY** (example)
# *  Bitcoin USD (**BTC-USD**) is a **cryptocurrency** with a **market capitalization** of \\$ 715 Billion.  The stock has been trading for the past year with an **average daily volume** of 27 Billion shares, with **share prices** ranging between \\$28,000 and \\$68,000.  Bitcoin is traded 24-hours a day, 7-days a week.

# %% [markdown]
# ---
# <a id="parameters"></a>
# ###  Yahoo! Finance Financial Information Parameter List
# **yf.Ticker(symbol).info**  will give a full list of the parameters.

# %%
'''
amzn = yf.Ticker('AMZN').info
ticker_parameter = pd.DataFrame(amzn).transpose()
ticker_parameter = ticker_parameter.reset_index() 
ticker_parameter.rename(columns={'index':'PARAMETERS'}, inplace=True)
ticker_parameter.sort_values(by=['PARAMETERS'],inplace=True)
ticker_parameter.reset_index(drop=True, inplace=True)

# remove ".head" to see the full list
print(ticker_parameter.sample(10))
print('\nAmazon (AMZN) has yf.Ticker parameters available: ', len(ticker_parameter))
'''
# Out:
#                    PARAMETERS
# 79   morningStarOverallRating
# 125               strikePrice
# 64                lastCapGain
# 115         sharesOutstanding
# 103      regularMarketDayHigh
# 91                   pegRatio
# 67                 lastMarket
# 108       regularMarketVolume
# 124                     state
# 150                     yield
#
# Amazon (AMZN) has yf.Ticker parameters available:  153

# %% [markdown]
# [go to top](#top)
#
# ---
# <a id="yf_download"></a>
# # 3.  Percentage Returns
# Download the tickers historical prices and dividends, as well as the market index values, and create a dataframe with percentage returns.
#
# - download historical prices `yf_returns`
# - download dividend data `yf_divdend`
# - create dataframe with percentage returns `yf_returns`
#
# ---
# <a id="yf_download_price"></a>
# ##  3.1  Download Historical Prices
# **yf.download** is used to get the historical prices of several securities for the time period `yf_period` with specified intervals `yf_interval`.
#
# **Steps:**
# 1.  Create dataframe **yf_price** with **yf.download**
# 2.  Select `Close` column only (price at market close)
# 3.  Remove the dataframe `multi-index`
# 4.  Calculate percentage changes with `pct_change`

# %%
#  print set parameters
print('SYMBOLS:\n{}\n'.format(symbols))
print('PERIOD:\t\t{}'.format(yf_period))
print('INTERVAL:\t{}'.format(yf_interval))
# Out:
# SYMBOLS:
# ['ABBV', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADM', 'ADP', 'AOS', 'ATVI', 'MMM', '^DJI', '^IXIC', '^GSPC']
#
# PERIOD:		10y
# INTERVAL:	1d

# %%
#  1.  Create dataframe yf_price with yf.download
yf_returns = yf.download(
        tickers = symbols,       # tickers list or string as well
        period = yf_period,      # optional, default is '1mo'
        interval = yf_interval,  # fetch data by interval
        group_by = 'ticker',     # group by ticker
        auto_adjust = True,      # adjust all OHLC (open-high-low-close)
        prepost = True,          # download market hours data
        threads = True,          # threads for mass downloading
        proxy = None)            # proxy


#  2.  Select 'Close' (price at market close) column only
yf_returns = yf_returns.iloc[:, yf_returns.columns.get_level_values(1)=='Close']


#  3.  Remove the dataframe multi-index
yf_returns.columns = yf_returns.columns.droplevel(1)  # multi-index


yf_returns.tail(10)
# Out:
# [*********************100%***********************]  506 of 506 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted
#                           MDLZ        STT          DE       INCY        QCOM  \
# Date
# 2022-12-12 00:00:00  67.379997  80.260002  437.049988  82.360001  121.209999
# 2022-12-13 00:00:00  67.599998  81.330002  437.190002  82.910004  123.489998
# 2022-12-14 00:00:00  67.260002  79.889999  438.440002  82.669998  121.709999
# 2022-12-15 00:00:00  66.389999  78.260002  429.790009  82.230003  116.639999
# 2022-12-16 00:00:00  66.160004  77.699997  431.089996  82.029999  114.529999
print('shape: ', yf_returns.shape)
# Out:
# shape:  (2518, 506)

# %% [markdown]
# ###   Percentage Change
# Percent change in prices is much more meaningful than the dollar value.  Using pandas `.pct_change` method to get the returns.
#
# \begin{align*}
# \mathsf{\frac{price_{2}-price_{1}}{price_{1}}} \times  100
# \end{align*}

# %%
#  4.  calculate percentage changes with "pct_change()"
#  multiply by 100 to get percentage value
#  round off the percentages to 2 decimal points
yf_returns = round(yf_returns.pct_change()*100, 2)


yf_returns.tail(10)
# Out:
#                      MDLZ   STT    DE  INCY  QCOM   EMN  CTSH   JPM  APTV  \
# Date
# 2022-12-12 00:00:00  0.48  1.56  0.52  0.02  1.81  1.54  1.20  1.55  3.03
# 2022-12-13 00:00:00  0.33  1.33  0.03  0.67  1.88  1.87  0.24 -0.10  1.53
# 2022-12-14 00:00:00 -0.50 -1.77  0.29 -0.29 -1.44 -2.01 -1.61 -0.50 -1.00
# 2022-12-15 00:00:00 -1.29 -2.04 -1.97 -0.53 -4.17 -4.62 -3.23 -2.48 -0.65
# 2022-12-16 00:00:00 -0.35 -0.72  0.30 -0.24 -1.81 -0.01 -1.40 -0.62 -2.59
# 2022-12-19 00:00:00 -0.70 -0.18  0.37 -1.76 -1.68 -1.97 -1.04  0.60 -0.40
# 2022-12-20 00:00:00  0.23  0.55  0.62  0.60 -0.45  0.26  0.11  0.48  0.63
# 2022-12-21 00:00:00  1.58  0.92  1.44 -0.68  2.22  1.04  1.07  1.12  0.47
# 2022-12-22 00:00:00 -0.24 -1.09 -1.31  0.75 -3.41 -0.45 -0.31 -1.13 -3.34
# 2022-12-23 00:00:00  0.49 -0.49  0.07 -0.17 -0.46  0.91  0.65  0.32  0.12
#
#                      MPWR  ...  BF.B   LYB   EMR   KIM   SWK  GOOGL  FISV  \
# Date                       ...
# 2022-12-12 00:00:00  1.79  ...   NaN  1.84  2.08  0.51  1.31   0.52  1.82
# 2022-12-13 00:00:00  2.16  ...   NaN  1.40  2.00  0.60  3.14   2.49 -0.89
# 2022-12-14 00:00:00 -1.53  ...   NaN -0.52 -0.36  0.27 -1.82  -0.59  0.34
# 2022-12-15 00:00:00 -5.59  ...   NaN -3.59 -2.53 -2.18 -3.95  -4.43 -3.38
# 2022-12-16 00:00:00 -1.68  ...   NaN -0.12 -0.30 -1.39 -2.25  -0.66  0.11
# 2022-12-19 00:00:00 -2.19  ...   NaN -0.35 -0.40 -1.18 -1.99  -2.02  0.09
# 2022-12-20 00:00:00 -0.32  ...   NaN  0.56  0.49 -0.29 -0.21   0.66  0.90
# 2022-12-21 00:00:00  2.55  ...   NaN  1.92  1.83  0.86 -1.82   0.63  1.59
# 2022-12-22 00:00:00 -5.29  ...   NaN -1.00 -1.76 -0.95  0.03  -2.03 -1.58
# 2022-12-23 00:00:00  0.00  ...   NaN  1.72  0.72  1.60  0.89   1.54  0.93
#
#                      SBUX   MGM   KDP
# Date
# 2022-12-12 00:00:00  0.89  1.51  0.42
# 2022-12-13 00:00:00 -0.57  1.52 -1.18
# 2022-12-14 00:00:00  0.08 -1.41 -0.80
# 2022-12-15 00:00:00 -2.15 -1.92 -1.90
# 2022-12-16 00:00:00 -1.16 -1.55 -1.53
# 2022-12-19 00:00:00 -0.54 -4.04  0.69
# 2022-12-20 00:00:00 -0.31  0.44 -0.17
# 2022-12-21 00:00:00  0.68  0.58  0.74
# 2022-12-22 00:00:00 -0.92 -2.37 -0.66
# 2022-12-23 00:00:00  0.21  0.12  0.01
#
# [10 rows x 506 columns]

# %% [markdown]
# [go to top](#top)
#
# ---
# <a id="yf_download_div"></a>
# ##  3.2 Download Dividend Percentages
# Dividends is a sum of money paid regularly by a company to its shareholders out of its profits.  Not all companies pay out dividends.

# %%
yf_divdend = pd.DataFrame()   # initialize dataframe

for i in ticker:
    if i != market_index:
        x = pd.DataFrame(yf.Ticker(i).dividends)
        x = x.rename(columns={"Dividends":i})
        yf_divdend = pd.concat([yf_divdend,x], axis=1)
        if len(x) > 0:
            print('{:>8}\t- dividends'.format(i))
        else:
            print('{:>8}\t- no dividends'.format(i))             


#  match dates in yf_returns (first return data to now)
yf_divdend = yf_divdend[yf_divdend.index >= yf_returns.index[0]]
# Out:
#        A	- dividends
#      AAL	- dividends
#      AAP	- dividends
#     AAPL	- dividends
#     ABBV	- dividends
#      ABC	- dividends
#     ABMD	- no dividends
#      ABT	- dividends
#     ACGL	- no dividends
#      ACN	- dividends
#     ADBE	- dividends
#      ADI	- dividends
#      ADM	- dividends
#      ADP	- dividends
#     ADSK	- dividends
#      AEE	- dividends
#      AEP	- dividends
#      AES	- dividends
#      AFL	- dividends
#      AIG	- dividends
#      AIZ	- dividends
#      AJG	- dividends
#     AKAM	- no dividends
#      ALB	- dividends
#     ALGN	- no dividends
#      ALK	- dividends
#      ALL	- dividends
#     ALLE	- dividends
#     AMAT	- dividends
#     AMCR	- dividends
#      AMD	- no dividends
#      AME	- dividends
#     AMGN	- dividends
#      AMP	- dividends
#      AMT	- dividends
#     AMZN	- no dividends
#     ANET	- no dividends
#     ANSS	- no dividends
#      AON	- dividends
#      AOS	- dividends
#      APA	- dividends
#      APD	- dividends
#      APH	- dividends
#     APTV	- dividends
#      ARE	- dividends
#      ATO	- dividends
#     ATVI	- dividends
#      AVB	- dividends
#     AVGO	- dividends
#      AVY	- dividends
#      AWK	- dividends
#      AXP	- dividends
#      AZO	- no dividends
#       BA	- dividends
#      BAC	- dividends
#     BALL	- no dividends
#      BAX	- dividends
#     BBWI	- dividends
#      BBY	- dividends
#      BDX	- dividends
#      BEN	- dividends
# BF.B: 1d data not available for startTime=-2208994789 and endTime=1671753872. Only 100 years worth of day granularity data are allowed to be fetched per request.
#     BF.B	- no dividends
#     BIIB	- no dividends
#      BIO	- no dividends
#       BK	- dividends
#     BKNG	- no dividends
#      BKR	- dividends
#      BLK	- dividends
#      BMY	- dividends
#       BR	- dividends
# Got error from yahoo api for ticker BRK.B, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# -
#       ON	- no dividends
#     ORCL	- dividends
#     ORLY	- no dividends
#     OTIS	- dividends
#      OXY	- dividends
#     PARA	- dividends
#     PAYC	- no dividends
#     PAYX	- dividends
#     PCAR	- dividends
#      PCG	- dividends
#     PEAK	- dividends
#      PEG	- dividends
#      PEP	- dividends
#      PFE	- dividends
#      PFG	- dividends
#       PG	- dividends
#      PGR	- dividends
#       PH	- dividends
#      PHM	- dividends
#      PKG	- dividends
#      PKI	- dividends
#      PLD	- dividends
#       PM	- dividends
#      PNC	- dividends
#      PNR	- dividends
#      PNW	- dividends
#     POOL	- dividends
#      PPG	- dividends
#      PPL	- dividends
#      PRU	- dividends
#      PSA	- dividends
#      PSX	- dividends
#      PTC	- no dividends
#      PWR	- dividends
#      PXD	- dividends
#     PYPL	- no dividends
#     QCOM	- dividends
#     QRVO	- no dividends
#      RCL	- dividends
#       RE	- dividends
#      REG	- dividends
#     REGN	- no dividends
#       RF	- dividends
#      RHI	- dividends
#      RJF	- dividends
#       RL	- dividends
#      RMD	- dividends
#      ROK	- dividends
#      ROL	- dividends
#      ROP	- dividends
#     ROST	- dividends
#      RSG	- dividends
#      RTX	- dividends
#     SBAC	- dividends
#     SBNY	- dividends
#     SBUX	- dividends
#     SCHW	- dividends
#     SEDG	- no dividends
#      SEE	- dividends
#      SHW	- dividends
#     SIVB	- dividends
#      SJM	- dividends
#      SLB	- dividends
#      SNA	- dividends
#     SNPS	- no dividends
#       SO	- dividends
#      SPG	- dividends
#     SPGI	- dividends
#      SRE	- dividends
#      STE	- dividends
#      STT	- dividends
#      STX	- dividends
#      STZ	- dividends
#      SWK	- dividends
#     SWKS	- dividends
#      SYF	- dividends
#      SYK	- dividends
#      SYY	- dividends
#        T	- dividends
#      TAP	- dividends
#      TDG	- dividends
#      TDY	- no dividends
#     TECH	- dividends
#      TEL	- dividends
#      TER	- dividends
#      TFC	- dividends
#      TFX	- dividends
#      TGT	- dividends
#      TJX	- dividends
#      TMO	- dividends
#     TMUS	- dividends
#      TPR	- dividends
#     TRGP	- dividends
#     TRMB	- no dividends
#     TROW	- dividends
#      TRV	- dividends
#     TSCO	- dividends
#     TSLA	- no dividends
#      TSN	- dividends
#       TT	- dividends
#     TTWO	- dividends
#      TXN	- dividends
#      TXT	- dividends
#      TYL	- dividends
#      UAL	- dividends
#      UDR	- dividends
#      UHS	- dividends
#     ULTA	- dividends
#      UNH	- dividends
#      UNP	- dividends
#      UPS	- dividends
#      URI	- no dividends
#      USB	- dividends
#        V	- dividends
#      VFC	- dividends
#     VICI	- dividends
#      VLO	- dividends
#      VMC	- dividends
#      VNO	- dividends
#     VRSK	- dividends
#     VRSN	- dividends
#     VRTX	- no dividends
#      VTR	- dividends
#     VTRS	- dividends
#       VZ	- dividends
#      WAB	- dividends
#      WAT	- no dividends
#      WBA	- dividends
#      WBD	- no dividends
#      WDC	- dividends
#      WEC	- dividends
#     WELL	- dividends
#      WFC	- dividends
#      WHR	- dividends
#       WM	- dividends
#      WMB	- dividends
#      WMT	- dividends
#      WRB	- dividends
#      WRK	- dividends
#      WST	- dividends
#      WTW	- dividends
#       WY	- dividends
#     WYNN	- dividends
#      XEL	- dividends
#      XOM	- dividends
#     XRAY	- dividends
#      XYL	- dividends
#      YUM	- dividends
#      ZBH	- dividends
#     ZBRA	- no dividends
#     ZION	- dividends
#      ZTS	- dividends
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     581             try:
# --> 582                 self._check_compatible_with(other)
#     583             except (TypeError, IncompatibleFrequency) as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py in _check_compatible_with(self, other, setitem)
#     460             return
# --> 461         self._assert_tzawareness_compat(other)
#     462         if setitem:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py in _assert_tzawareness_compat(self, other)
#     697         elif other_tz is None:
# --> 698             raise TypeError(
#     699                 "Cannot compare tz-naive and tz-aware datetime-like objects"
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#    1053         try:
# -> 1054             other = self._validate_comparison_value(other)
#    1055         except InvalidComparison:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     584                 # e.g. tzawareness mismatch
# --> 585                 raise InvalidComparison(other) from err
#     586
#
# InvalidComparison: 2012-12-24 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13372/3136094214.py in <module>
#      13
#      14 #  match dates in yf_returns (first return data to now)
# ---> 15 yf_divdend = yf_divdend[yf_divdend.index >= yf_returns.index[0]]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      60     @unpack_zerodim_and_defer("__ge__")
#      61     def __ge__(self, other):
# ---> 62         return self._cmp_method(other, operator.ge)
#      63
#      64     # -------------------------------------------------------------
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in _cmp_method(self, other, op)
#    7016
#    7017         elif isinstance(self._values, ExtensionArray):
# -> 7018             result = op(self._values, other)
#    7019
#    7020         elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      60     @unpack_zerodim_and_defer("__ge__")
#      61     def __ge__(self, other):
# ---> 62         return self._cmp_method(other, operator.ge)
#      63
#      64     # -------------------------------------------------------------
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#    1054             other = self._validate_comparison_value(other)
#    1055         except InvalidComparison:
# -> 1056             return invalid_comparison(self, other, op)
#    1057
#    1058         dtype = getattr(other, "dtype", None)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/invalid.py in invalid_comparison(left, right, op)
#      34     else:
#      35         typ = type(right).__name__
# ---> 36         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37     return res_values
#      38
#
# TypeError: Invalid comparison between dtype=datetime64[ns, America/New_York] and Timestamp

# %%
test = yf.Ticker('DJI').dividends

# %% [markdown]
# ###  Dividend Analysis:
# -  not all companies have dividend payouts
# -  dividend payouts are typically less than 5%
# -  FBGRX, QQQ and VBTLX have some dividend payouts
#
#
# [go to top](#top)
#
# ---
# <a id="yf_download_div"></a>
# ##  3.3 Calculate Percentage Returns
# Add returns and dividend dataframes.
#
# <span style="color:b"><font size="5">yf_returns = yf_returns + yf_divdend</font></span>
#
# Basically, we're doing:
#
# \begin{align*}
# \mathsf{\text{Percentage Return} =  \frac{price_{2}-price_{1}}{price_{1}}} \times  100 + dividends (\%)
# \end{align*}

# %%
yf_returns = yf_returns

yf_returns.tail(5)
# Out:
#                      MDLZ   STT    DE  INCY  QCOM   EMN  CTSH   JPM  APTV  \
# Date
# 2022-12-19 00:00:00 -0.70 -0.18  0.37 -1.76 -1.68 -1.97 -1.04  0.60 -0.40
# 2022-12-20 00:00:00  0.23  0.55  0.62  0.60 -0.45  0.26  0.11  0.48  0.63
# 2022-12-21 00:00:00  1.58  0.92  1.44 -0.68  2.22  1.04  1.07  1.12  0.47
# 2022-12-22 00:00:00 -0.24 -1.09 -1.31  0.75 -3.41 -0.45 -0.31 -1.13 -3.34
# 2022-12-23 00:00:00  0.49 -0.49  0.07 -0.17 -0.46  0.91  0.65  0.32  0.12
#
#                      MPWR  ...  BF.B   LYB   EMR   KIM   SWK  GOOGL  FISV  \
# Date                       ...
# 2022-12-19 00:00:00 -2.19  ...   NaN -0.35 -0.40 -1.18 -1.99  -2.02  0.09
# 2022-12-20 00:00:00 -0.32  ...   NaN  0.56  0.49 -0.29 -0.21   0.66  0.90
# 2022-12-21 00:00:00  2.55  ...   NaN  1.92  1.83  0.86 -1.82   0.63  1.59
# 2022-12-22 00:00:00 -5.29  ...   NaN -1.00 -1.76 -0.95  0.03  -2.03 -1.58
# 2022-12-23 00:00:00  0.00  ...   NaN  1.72  0.72  1.60  0.89   1.54  0.93
#
#                      SBUX   MGM   KDP
# Date
# 2022-12-19 00:00:00 -0.54 -4.04  0.69
# 2022-12-20 00:00:00 -0.31  0.44 -0.17
# 2022-12-21 00:00:00  0.68  0.58  0.74
# 2022-12-22 00:00:00 -0.92 -2.37 -0.66
# 2022-12-23 00:00:00  0.21  0.12  0.01
#
# [5 rows x 506 columns]

# %% [markdown]
# ---
# <a id="yf_download_clean"></a>
# ##  3.4 Clean-Up Return's Dataframe
# Return's dataframe `yf_returns` involves:
# 1. re-order columns
# 2. rename market index columns
# 3. update `market_index` with market names
# 4. update `symbols` list with market names

# %%
#  1. re-order columns
col_order = []

for i in market_index:
    col_order.append(i)  # add markets

for i in ticker:
    col_order.append(i)  # add tickers

yf_returns = yf_returns[col_order]   # reorder columns


#  2. rename market index columns
yf_returns.rename(columns = {'^DJI':'DowJones', '^GSPC':'S&P500', '^IXIC':'Nasdaq'}, inplace = True)


#  3. update 'market_index' with market names
market_index = sorted(['DowJones', 'S&P500', 'Nasdaq'])


#  4. update `symbols` list with market names
symbols[symbols.index('^DJI')]  = 'DowJones'
symbols[symbols.index('^GSPC')] = 'S&P500'
symbols[symbols.index('^IXIC')] = 'Nasdaq'


print(yf_returns.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2519 entries, 2012-12-24 00:00:00 to 2022-12-23 00:00:00
# Columns: 506 entries, DowJones to ZTS
# dtypes: float64(506)
# memory usage: 9.7+ MB
# None

# %% [markdown]
# [go to top](#top)
#
# ---
# <a id="perf"></a>
# # 4  Performance Analysis
# The stock prices and dividends have been downloaded and the percent changes have been caluculated.  Before we can begin the analysis, we need to create dataframes for the various time periods we want to analyze:
#
# | dataframe | description | column | function |
# | :--- | :--- | ---: | :--- |
# | perf_dy | daily percentage change | `Date` | `= yf_returns` |
# | perf_yr | total annual percentage change | `YEAR` | `groupby YEAR` |
# | perf_mh | total monthly percentage change | `YEAR-MONTH` | `groupby MONTH` |
# | perf_wk | total weekly percentage change | `YEAR-WEEK` | `groupby WEEK` |
#
#
# ### Performance Analysis:
# [4.1 Performance - YEARLY](#perf_yr)<br>
# [4.2 Performance - MONTHLY](#perf_mh)<br>
# [4.3 Performance - WEEKLY](#perf_wk)<br>
# [4.4 Performance - DAILY](#perf_dy)<br>
#
# ---
#
# ###  Create Performance Dataframes

# %%
#  create YEAR, MONTH, WEEK columns in perf_dy
perf_dy = yf_returns
perf_dy['YEAR']  = perf_dy.index.strftime("%Y")     # YEAR
perf_dy['MONTH'] = perf_dy.index.strftime("%Y-%m")  # YEAR-MONTH
perf_dy['WEEK']  = perf_dy.index.strftime("%Y-%U")  # YEAR-WEEK


#  create time dataframes using GROUPBY
perf_yr = perf_dy.groupby('YEAR').sum()
perf_mh = perf_dy.groupby('MONTH').sum()
perf_wk = perf_dy.groupby('WEEK').sum()


#  print index and column names
print("\nperf_dy:\n", perf_dy.index.name, perf_dy.columns.values)
print("\nperf_yr:\n", perf_yr.index.name, perf_yr.columns.values)
print("\nperf_mh:\n", perf_mh.index.name, perf_mh.columns.values)
print("\nperf_wk:\n", perf_wk.index.name, perf_wk.columns.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1090/710131435.py in <module>
#       1 #  create YEAR, MONTH, WEEK columns in perf_dy
#       2 perf_dy = yf_returns
# ----> 3 perf_dy['YEAR']  = perf_dy.index.strftime("%Y")     # YEAR
#       4 perf_dy['MONTH'] = perf_dy.index.strftime("%Y-%m")  # YEAR-MONTH
#       5 perf_dy['WEEK']  = perf_dy.index.strftime("%Y-%U")  # YEAR-WEEK
#
# AttributeError: 'Index' object has no attribute 'strftime'

# %% [markdown]
# ---
# ###  Create Function:  plotPerformance

# %%
#  create function to plot market and indexes
def plotPerformance(arg):
    df = arg
    
    plt.figure(figsize=(10,8))

    #  subplot #1
    plt.subplot(221)
    df[market_index].boxplot()
    plt.title('market indexes')
    plt.ylabel('percent change')
    plt.xticks(rotation = 90)
    plt.grid(False)

    #  subplot #2
    plt.subplot(222)
    plt.plot(df[market_index])
    plt.title('market indexes')
    plt.legend(df[market_index], loc="upper left", bbox_to_anchor=(1,1))
    plt.xticks(rotation = 90)
    
    plt.show()  # plot subplots
    
    #  plot #3
    plt.figure(figsize=(10,6))
    df[ticker].boxplot()
    plt.title('SYMBOLS', fontsize = 14)
    plt.ylabel('percent change', fontsize = 14)
    plt.xticks(rotation = 90)
    plt.grid(False)
    plt.show()
    
    #  plot #4
    plt.figure(figsize=(10,6))
    plt.plot(df[ticker])
    plt.title('SYMBOLS', fontsize = 14)
    plt.ylabel('percent change', fontsize = 14)
    plt.legend(df[ticker], loc="upper left", bbox_to_anchor=(1,1))
    plt.xticks(rotation = 90)
    plt.show()
    

    #  print returns
    print('\nRETURNS FROM {} TO {}:'.format(df.index[0], df.index[-1]))
    for i in market_index + ticker:
        print('{:>10}{:>10.2f}%'.format(i,df[i].sum()))

    return

print('function plotPerformance created')
# Out:
# function plotPerformance created

# %% [markdown]
# [go to top of section](#perf)
#
# ---
# <a id="perf_yr"></a>
# ##  4.1 Performance - YEARLY
# Plot and analyze the yearly performance for the past 10 years (past decade).

# %%
plotPerformance(perf_yr.tail(10))  # past 10 years
# Out:
# RETURNS FROM 2013 TO 2022:
#   DowJones    108.02%
#     Nasdaq    145.99%
#     S&P500    114.52%
#       ABBV    230.34%
#       ABMD    438.75%
#        ABT    168.58%
#        ACN    185.67%
#       ADBE    269.06%
#        ADM    181.51%
#        ADP    204.27%
#        AOS    176.09%
#       ATVI    255.64%
#        MMM     75.90%

# %% [markdown]
# ### ANALYSIS - YEARLY (10 years)
# `market index`
# - **boxplot** - all three indexes stay within similar range, however, **S&P500** dips  more than the other two markets
# - **lineplot** - all three markets following the same path.  Nasdaq did see a significant increase in 2019-2020.
# - **returns** - all three markets doubled
#
# `symbols`
# - **boxplot** and **lineplots** - `AMZN` and `TWTR` are volitile, with significant percent changes.  `VBTLX` has a very tight range
# - **returns** - `AMZN` had the best returns and all the securities beat the **S&P500** except `VBTLX`
#
#
# [go to top of section](#perf)
#
# ---
# <a id="perf_mh"></a>
# ##  4.2 Performance - MONTHLY
# Plot and analyze the yearly performance for the past 24 months (2 years).

# %%
plotPerformance(perf_mh.tail(24))  # past 24 months
# Out:
# RETURNS FROM 2021-01 TO 2022-12:
#   DowJones     10.80%
#     Nasdaq    -13.80%
#     S&P500      6.06%
#       ABBV     52.26%
#       ABMD     40.89%
#        ABT      6.44%
#        ACN     10.71%
#       ADBE    -24.47%
#        ADM     72.86%
#        ADP     38.27%
#        AOS     14.31%
#       ATVI    -10.72%
#        MMM    -27.81%

# %% [markdown]
# ### ANALYSIS - MONTHLY (24 months)
# `market index`
# - **boxplot** - all three indexes stay within similar range, however, **Nasdaq** was volitile
# - **lineplot** - all three markets following the same path
# - **returns** - all three markets returned over 25%
#
# `symbols`
# - **boxplot** and **lineplots** - `FLT` and `TWTR` are volitile, with significant percent changes.  `VBTLX` has a very tight range
# - **returns** - `TWTR` had the best returns, with `FBGRX`, `QQQ` and `TWTR` beating the **S&P500**
#
#
# [go to top of section](#perf)
#
# ---
# <a id="perf_wk"></a>
# ##  4.3 Performance - WEEKLY
# Plot and analyze the yearly performance for the past 26 weeks (6 months).

# %%
plotPerformance(perf_wk.tail(26))  # past 26 weeks
# Out:
# RETURNS FROM 2022-26 TO 2022-51:
#   DowJones      6.17%
#     Nasdaq     -7.95%
#     S&P500     -0.45%
#       ABBV      8.05%
#       ABMD     51.85%
#        ABT      0.31%
#        ACN     -9.17%
#       ADBE     -8.47%
#        ADM     26.09%
#        ADP     11.60%
#        AOS      4.33%
#       ATVI     -2.10%
#        MMM     -8.68%

# %% [markdown]
# ### ANALYSIS - WEEKLY (26 weeks)
# `market index`
# - **boxplot** - **Nasdaq** was volitile, but all three indexes had major swings (outliers)
# - **lineplot** - all three markets following the same path
# - **returns** - all three markets dipped
#
# `symbols`
# - **boxplot** - all securities performed poorly, with `AMZN`, `FBGRX` and `TWTR` experiencing wild swings (outliers)
# - **lineplots** - all securities had swings
# - **returns** - returns were bad for all securities
#
#
# [go to top of section](#perf)
#
# ---
# <a id="perf_dy"></a>
# ##  4.4 Performance - DAILY
# Plot and analyze the yearly performance for the past 31 days (1 month).

# %%
plotPerformance(perf_dy.tail(31))  # past 31 days
# Out:
# RETURNS FROM 2022-11-10 00:00:00 TO 2022-12-23 00:00:00:
#   DowJones      2.24%
#     Nasdaq      1.94%
#     S&P500      2.76%
#       ABBV     10.11%
#       ABMD      1.88%
#        ABT      8.60%
#        ACN      0.83%
#       ADBE     13.56%
#        ADM      1.98%
#        ADP      0.92%
#        AOS      3.75%
#       ATVI      6.00%
#        MMM     -2.41%

# %% [markdown]
# ### ANALYSIS - DAILY (31 days)
# `market index`
# - **boxplot** - **Nasdaq** was volitile, but all three indexes had major swings (outliers)
# - **lineplot** - all three markets following the same path
# - **returns** - all three markets dipped
#
# `symbols`
# - **boxplot** - all securities performed poorly, with `TWTR` experiencing wild swings (outliers)
# - **lineplots** - all securities had swings,  with `TWTR` having the most
# - **returns** - returns were bad for all securities except `TWTR`
#
#
# [go to top of section](#perf)
#
#
# **Generally speaking** securities that follow or out-perform the **S&P500** are generally good long-term investments.

# %% [markdown]
# [go to top](#top)
#
# ---
# <a id="stock_markets"></a>
# #  5.  Financial Markets and Investment Overview
# * All trading occurs in **financial markets** and the performances of the various components of the financial markets are measured by **market indexes**
# * **Financial** and **Investment Instruments** are traded in the financial markets and overall performances is tracked on the market indexes
#
#
# <a id="fin_markets"></a>
# ##  5.1  Financial Markets
# Following are some of the major stock markets and their market capitalizations:
#
# |  STOCK EXCHANGE  |  SYMBOL  |  CITY  |  MARKET CAP 2019 (\$B) |
# | :--- | :---: | :--- | ---: |
# | New York Stock Exchange | NYSE | New York City | 22,923 |
# | Nasdaq | NASDAQ | New York City | 10,857 |
# | Japan Exchange Group | JPX | Tokyo | 5,679 |
# | Shanghai Stock Exchange | SSE | Shanghai | 4,026 |
# | Hong Kong Stock Exchange | SEHK | Hong Kong | 3,936 |
# | London Stock Exchange | LSE | London | 3,767 |
# | Shenzhen Stock Exchange | SZSE | Shenzhen | 2,504 |
# | TMX Group | TSX | Toronto | 2,095 |
# | Bombay Stock Exchange | BSE | Mumbai | 2,056 |
# | Australian Securities Exchange | ASX | Sydney | 1,328 |
# | Ho Chi Minh Stock Exchange | HSX | Ho Chi Minh | 128 |
# | Pakistan Stock Exchange | PSX | Karachi | 54  |
#
#
# <a id="market_index"></a>
# ##  5.2  Market Indexes
# Following are the major market indexes:
#
# |  MARKET INDEX  |  SYMBOL |Description |
# | :--- | :--- | :--- |
# | **Dow Jones Industrial Average** | DJIA| or Dow, is an index that tracks the 30 largest, publicly owned companies trading on the New York Stock Exchange** | NYSE) and the NASDAQ. |
# |**Nasdaq Composite** | IXIC| or Nasdaq, is an index of more than 3,000 stocks listed on the Nasdaq exchange. |
# |**Standard & Poor's 500 Index** | GSPC| or S&P 500, is an index of the 500 largest U.S. publicly traded companies. The index is widely regarded as the best gauge of large-cap U.S. equities. S&P500 is the **market benchmark**. |
# |**CBOE Volatility Index10** | VIX | is a real-time market index that represents the market's expectation of 30-day forward-looking volatility and is derived from the price inputs of the S&P500 index options. It is also known by "Fear Gauge" or "Fear Index." |
# |**Financial Times Stock Exchange 100 Share Index** | FTSE |or *Footsie*, is the dominant index, containing 100 of the top blue chips on the London Stock Exchange. |
# |**Nikkei Index** | N225 | is composed of Japan's top 225 blue-chip companies traded on the Tokyo Stock Exchange. |
# |**Hang Seng Index** | HSI | is an index of the largest companies that trade on the Hong Kong Exchange. |
# |**Sensex** | BSESB | also known as the S&P BSE Sensex index, is the benchmark index comprising of 30 of the largest and most actively-traded stocks on the Bombay Stock Exchange. |
# |**Karachi Stock Exchange** | KSE-100 | consists of 100 companies representing about 90 percent of market capitalization of the Pakistan Stock Exchange. |
#
#
# <a id="fin_inst"></a>
# ##  5.3  Financial Instruments
# Financial instruments can also be referred to as **securities**, and typically comprise of:
#
# |  SECURITY |Description |
# | :--- | :--- |
# | **Stocks** | an ownership position in a publicly-traded corporation |
# | **Bonds** | a creditor relationship with a governmental body or a corporation |
# | **Derivative (Options)** | or rights to ownership – also called underlying financial instrument |
#
#
# <a id="inv_inst"></a>
# ##  5.4  Investment Instruments
# Investment vehicles are very popular and are securities packaged in **portfolios** to maximize gains and minimize risks.
#
# |  INSTRUMENT |Description |  |
# | :--- | :--- | |
# | **Mutual Funds** | A mutual fund is a company that pools money from many investors and invests in securities such as stocks, bonds, and short-term debt (bonds). The combined holdings of the mutual fund are known as its *portfolio*. |
# | **Exchange-Traded Funds (ETF)** |are in many ways similar to mutual funds, however, they are listed on exchanges and ETF shares trade throughout the day just like ordinary stock. |
# | **Index and Sector Funds** |is similar to an ETF, except the index fund portfolio consists of securities listed on a particular market index (such as Nasdaq or S&P500). |
# | **Hedge Funds** |have very aggressive portfolios and are very high-risk. Hedge-funds are tailored to high-end investor. |
# | **Real Estate Investment Trusts (REITs)** |allow individuals to invest in large-scale, income-producing real estate. |
# | **Certificate of Deposit (CD)** |is a savings account that holds a fixed amount of money for a fixed period of time, and are considered to be one of the safest savings option. |

# %% [markdown]
# [go to top of document](#top)
#
# ---
#
# # END
#
# Please upvote if you found this useful :-)
